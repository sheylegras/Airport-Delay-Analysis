# %% [markdown]
# # Table of Contents
# 01. Importing Libraries
# 02. Importing Data
# 03. Exploring Relationships

# %% [markdown]
# ## 01. Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
#checking matplotlib version
matplotlib.__version__
# Out:
# '3.5.2'

# %%
# %matplotlib inline

# %% [markdown]
# ## 02. Importing Data

# %%
#define path
path = r'C:\Users\legra\Desktop\08-2022 Airline Delays Analysis'

# %%
#import data
df = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'airline_delay_wrangled.csv'), index_col = False)

# %%
#checking df
df.shape
# Out:
# (38701, 22)

# %%
df.head()
# Out:
#    Unnamed: 0  year  month carrier       carrier_name airport  \
# 0           0  2021     12      9E  Endeavor Air Inc.     ABE
# 1           1  2021     12      9E  Endeavor Air Inc.     ABY
# 2           2  2021     12      9E  Endeavor Air Inc.     AEX
# 3           3  2021     12      9E  Endeavor Air Inc.     AGS
# 4           4  2021     12      9E  Endeavor Air Inc.     ALB
#
#                                         airport_name  arriving_flight_count  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...                  127.0
# 1             Albany, GA: Southwest Georgia Regional                   73.0
# 2           Alexandria, LA: Alexandria International                   62.0
# 3        Augusta, GA: Augusta Regional at Bush Field                  166.0
# 4                   Albany, NY: Albany International                   52.0
#
#    arrival_delayed_15_minutes_more  carrier_delay_count  ...  \
# 0                              9.0                 2.51  ...
# 1                             11.0                 5.02  ...
# 2                              8.0                 2.63  ...
# 3                             18.0                 8.53  ...
# 4                              6.0                 3.15  ...
#
#    security_delay_count  late_aircraft_count  arrival_cancelled_count  \
# 0                   0.0                 2.95                      0.0
# 1                   0.0                 1.87                      0.0
# 2                   0.0                 1.15                      0.0
# 3                   0.0                 2.74                      0.0
# 4                   0.0                 0.82                      0.0
#
#    arrival_diverted_count  arrival_delay_minutes  carrier_delay_minutes  \
# 0                     0.0                  264.0                  119.0
# 1                     0.0                  342.0                  125.0
# 2                     0.0                  439.0                  156.0
# 3                     1.0                 1266.0                  291.0
# 4                     0.0                  497.0                  278.0
#
#    weather_delay_minutes  nas_delay_minutes  security_delay_minutes  \
# 0                    0.0               68.0                     0.0
# 1                    0.0              142.0                     0.0
# 2                    0.0              103.0                     0.0
# 3                  693.0              167.0                     0.0
# 4                  180.0               21.0                     0.0
#
#    late_aircraft_delay_minutes
# 0                         77.0
# 1                         75.0
# 2                        180.0
# 3                        115.0
# 4                         18.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 03. Exploring Relationships

# %% [markdown]
# ### Correlations

# %%
#create a correlation matrix using pandas
df.corr()
# Out:
#                                  Unnamed: 0      year     month  \
# Unnamed: 0                         1.000000 -0.865686 -0.541682
# year                              -0.865686  1.000000  0.051017
# month                             -0.541682  0.051017  1.000000
# arriving_flight_count             -0.027426  0.032286  0.002880
# arrival_delayed_15_minutes_more   -0.113753  0.116391  0.033786
# carrier_delay_count               -0.143156  0.136507  0.059629
# weather_delay_count               -0.079241  0.092343  0.008064
# nas_delay_count                   -0.051329  0.062204 -0.002216
# security_delay_count              -0.097887  0.092231  0.038199
# late_aircraft_count               -0.117595  0.119640  0.037102
# arrival_cancelled_count            0.088285 -0.066101 -0.068897
# arrival_diverted_count            -0.049094  0.053863  0.009178
# arrival_delay_minutes             -0.107033  0.112433  0.026214
# carrier_delay_minutes             -0.112696  0.110052  0.040547
# weather_delay_minutes             -0.068943  0.087196 -0.004517
# nas_delay_minutes                 -0.050419  0.066356 -0.010352
# security_delay_minutes            -0.085820  0.086068  0.024596
# late_aircraft_delay_minutes       -0.113049  0.116665  0.031696
#
#                                  arriving_flight_count  \
# Unnamed: 0                                   -0.027426
# year                                          0.032286
# month                                         0.002880
# arriving_flight_count                         1.000000
# arrival_delayed_15_minutes_more               0.858726
# carrier_delay_count                           0.822621
# weather_delay_count                           0.625485
# nas_delay_count                               0.791360
# security_delay_count                          0.437032
# late_aircraft_count                           0.759703
# arrival_cancelled_count                       0.390241
# arrival_diverted_count                        0.602312
# arrival_delay_minutes                         0.830495
# carrier_delay_minutes                         0.822077
# weather_delay_minutes                         0.555439
# nas_delay_minutes                             0.721720
# security_delay_minutes                        0.367977
# late_aircraft_delay_minutes                   0.743047
#
#                                  arrival_delayed_15_minutes_more  \
# Unnamed: 0                                             -0.113753
# year                                                    0.116391
# month                                                   0.033786
# arriving_flight_count                                   0.858726
# arrival_delayed_15_minutes_more                         1.000000
# carrier_delay_count                                     0.935713
# weather_delay_count                                     0.691257
# nas_delay_count                                         0.882913
# security_delay_count                                    0.501655
# late_aircraft_count                                     0.945929
# arrival_cancelled_count                                 0.239910
# arrival_diverted_count                                  0.694723
# arrival_delay_minutes                                   0.966836
# carrier_delay_minutes                                   0.893164
# weather_delay_minutes                                   0.624273
# nas_delay_minutes                                       0.855693
# security_delay_minutes                                  0.414340
# late_aircraft_delay_minutes                             0.929540
#
#                                  carrier_delay_count  weather_delay_count  \
# Unnamed: 0                                 -0.143156            -0.079241
# year                                        0.136507             0.092343
# month                                       0.059629             0.008064
# arriving_flight_count                       0.822621             0.625485
# arrival_delayed_15_minutes_more             0.935713             0.691257
# carrier_delay_count                         1.000000             0.698336
# weather_delay_count                         0.698336             1.000000
# nas_delay_count                             0.707257             0.584091
# security_delay_count                        0.473950             0.321320
# late_aircraft_count                         0.861076             0.550102
# arrival_cancelled_count                     0.216440             0.143445
# arrival_diverted_count                      0.628689             0.591298
# arrival_delay_minutes                       0.919571             0.757545
# carrier_delay_minutes                       0.949222             0.752558
# weather_delay_minutes                       0.627627             0.938537
# nas_delay_minutes                           0.695715             0.620856
# security_delay_minutes                      0.398803             0.281065
# late_aircraft_delay_minutes                 0.837724             0.599105
#
#                                  nas_delay_count  security_delay_count  \
# Unnamed: 0                             -0.051329             -0.097887
# year                                    0.062204              0.092231
# month                                  -0.002216              0.038199
# arriving_flight_count                   0.791360              0.437032
# arrival_delayed_15_minutes_more         0.882913              0.501655
# carrier_delay_count                     0.707257              0.473950
# weather_delay_count                     0.584091              0.321320
# nas_delay_count                         1.000000              0.440088
# security_delay_count                    0.440088              1.000000
# late_aircraft_count                     0.760574              0.462171
# arrival_cancelled_count                 0.240454              0.089050
# arrival_diverted_count                  0.644641              0.342573
# arrival_delay_minutes                   0.837901              0.470453
# carrier_delay_minutes                   0.700176              0.438082
# weather_delay_minutes                   0.537844              0.273786
# nas_delay_minutes                       0.950732              0.406268
# security_delay_minutes                  0.361039              0.841169
# late_aircraft_delay_minutes             0.765230              0.452123
#
#                                  late_aircraft_count  arrival_cancelled_count  \
# Unnamed: 0                                 -0.117595                 0.088285
# year                                        0.119640                -0.066101
# month                                       0.037102                -0.068897
# arriving_flight_count                       0.759703                 0.390241
# arrival_delayed_15_minutes_more             0.945929                 0.239910
# carrier_delay_count                         0.861076                 0.216440
# weather_delay_count                         0.550102                 0.143445
# nas_delay_count                             0.760574                 0.240454
# security_delay_count                        0.462171                 0.089050
# late_aircraft_count                         1.000000                 0.213115
# arrival_cancelled_count                     0.213115                 1.000000
# arrival_diverted_count                      0.634160                 0.183291
# arrival_delay_minutes                       0.901087                 0.235751
# carrier_delay_minutes                       0.792489                 0.231596
# weather_delay_minutes                       0.485704                 0.139206
# nas_delay_minutes                           0.735660                 0.224639
# security_delay_minutes                      0.374130                 0.066933
# late_aircraft_delay_minutes                 0.966507                 0.206203
#
#                                  arrival_diverted_count  \
# Unnamed: 0                                    -0.049094
# year                                           0.053863
# month                                          0.009178
# arriving_flight_count                          0.602312
# arrival_delayed_15_minutes_more                0.694723
# carrier_delay_count                            0.628689
# weather_delay_count                            0.591298
# nas_delay_count                                0.644641
# security_delay_count                           0.342573
# late_aircraft_count                            0.634160
# arrival_cancelled_count                        0.183291
# arrival_diverted_count                         1.000000
# arrival_delay_minutes                          0.728902
# carrier_delay_minutes                          0.647800
# weather_delay_minutes                          0.559140
# nas_delay_minutes                              0.709867
# security_delay_minutes                         0.290176
# late_aircraft_delay_minutes                    0.671203
#
#                                  arrival_delay_minutes  carrier_delay_minutes  \
# Unnamed: 0                                   -0.107033              -0.112696
# year                                          0.112433               0.110052
# month                                         0.026214               0.040547
# arriving_flight_count                         0.830495               0.822077
# arrival_delayed_15_minutes_more               0.966836               0.893164
# carrier_delay_count                           0.919571               0.949222
# weather_delay_count                           0.757545               0.752558
# nas_delay_count                               0.837901               0.700176
# security_delay_count                          0.470453               0.438082
# late_aircraft_count                           0.901087               0.792489
# arrival_cancelled_count                       0.235751               0.231596
# arrival_diverted_count                        0.728902               0.647800
# arrival_delay_minutes                         1.000000               0.944752
# carrier_delay_minutes                         0.944752               1.000000
# weather_delay_minutes                         0.711316               0.694532
# nas_delay_minutes                             0.860004               0.713219
# security_delay_minutes                        0.406459               0.385632
# late_aircraft_delay_minutes                   0.938913               0.824144
#
#                                  weather_delay_minutes  nas_delay_minutes  \
# Unnamed: 0                                   -0.068943          -0.050419
# year                                          0.087196           0.066356
# month                                        -0.004517          -0.010352
# arriving_flight_count                         0.555439           0.721720
# arrival_delayed_15_minutes_more               0.624273           0.855693
# carrier_delay_count                           0.627627           0.695715
# weather_delay_count                           0.938537           0.620856
# nas_delay_count                               0.537844           0.950732
# security_delay_count                          0.273786           0.406268
# late_aircraft_count                           0.485704           0.735660
# arrival_cancelled_count                       0.139206           0.224639
# arrival_diverted_count                        0.559140           0.709867
# arrival_delay_minutes                         0.711316           0.860004
# carrier_delay_minutes                         0.694532           0.713219
# weather_delay_minutes                         1.000000           0.594532
# nas_delay_minutes                             0.594532           1.000000
# security_delay_minutes                        0.244266           0.352525
# late_aircraft_delay_minutes                   0.542149           0.767942
#
#                                  security_delay_minutes  \
# Unnamed: 0                                    -0.085820
# year                                           0.086068
# month                                          0.024596
# arriving_flight_count                          0.367977
# arrival_delayed_15_minutes_more                0.414340
# carrier_delay_count                            0.398803
# weather_delay_count                            0.281065
# nas_delay_count                                0.361039
# security_delay_count                           0.841169
# late_aircraft_count                            0.374130
# arrival_cancelled_count                        0.066933
# arrival_diverted_count                         0.290176
# arrival_delay_minutes                          0.406459
# carrier_delay_minutes                          0.385632
# weather_delay_minutes                          0.244266
# nas_delay_minutes                              0.352525
# security_delay_minutes                         1.000000
# late_aircraft_delay_minutes                    0.376482
#
#                                  late_aircraft_delay_minutes
# Unnamed: 0                                         -0.113049
# year                                                0.116665
# month                                               0.031696
# arriving_flight_count                               0.743047
# arrival_delayed_15_minutes_more                     0.929540
# carrier_delay_count                                 0.837724
# weather_delay_count                                 0.599105
# nas_delay_count                                     0.765230
# security_delay_count                                0.452123
# late_aircraft_count                                 0.966507
# arrival_cancelled_count                             0.206203
# arrival_diverted_count                              0.671203
# arrival_delay_minutes                               0.938913
# carrier_delay_minutes                               0.824144
# weather_delay_minutes                               0.542149
# nas_delay_minutes                                   0.767942
# security_delay_minutes                              0.376482
# late_aircraft_delay_minutes                         1.000000

# %%
#create a correlation heatmap using matplotlib
plt.matshow(df.corr())
plt.show()

# %%
#add labels, legend, and change size of heatmap

#figure size
f = plt.figure(figsize=(18,18)) 
#type of plot
plt.matshow(df.corr(), fignum=f.number)
#x axis label
plt.xticks(range(df.shape[1]), df.columns, fontsize=12, rotation=45)
#y axis label
plt.yticks(range(df.shape[1]), df.columns, fontsize=12)
#add color legend
cb = plt.colorbar()
#add font size
cb.ax.tick_params(labelsize=14)
#add title
plt.title('Correlation Matrix', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# ### Create a correlation heatmap using seaborn:

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'year', 'month', 'carrier', 'carrier_name', 'airport',
#        'airport_name', 'arriving_flight_count',
#        'arrival_delayed_15_minutes_more', 'carrier_delay_count',
#        'weather_delay_count', 'nas_delay_count', 'security_delay_count',
#        'late_aircraft_count', 'arrival_cancelled_count',
#        'arrival_diverted_count', 'arrival_delay_minutes',
#        'carrier_delay_minutes', 'weather_delay_minutes', 'nas_delay_minutes',
#        'security_delay_minutes', 'late_aircraft_delay_minutes'],
#       dtype='object')

# %%
#create a subset excluding month, year, carrier, airport
sub = df[['carrier_name', 'airport_name', 'arriving_flight_count', 'arrival_delayed_15_minutes_more', 'carrier_delay_count', 'weather_delay_count', 'nas_delay_count', 'security_delay_count', 'late_aircraft_count', 'arrival_cancelled_count', 'arrival_diverted_count', 'arrival_delay_minutes', 'carrier_delay_minutes', 'weather_delay_minutes', 'nas_delay_minutes', 'security_delay_minutes', 'late_aircraft_delay_minutes']]

# %%
sub
# Out:
#             carrier_name                                       airport_name  \
# 0      Endeavor Air Inc.  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...
# 1      Endeavor Air Inc.             Albany, GA: Southwest Georgia Regional
# 2      Endeavor Air Inc.           Alexandria, LA: Alexandria International
# 3      Endeavor Air Inc.        Augusta, GA: Augusta Regional at Bush Field
# 4      Endeavor Air Inc.                   Albany, NY: Albany International
# ...                  ...                                                ...
# 38696   Republic Airline                   Tucson, AZ: Tucson International
# 38697   Republic Airline                  Traverse City, MI: Cherry Capital
# 38698   Republic Airline                        Knoxville, TN: McGhee Tyson
# 38699   Republic Airline  Valparaiso, FL: Eglin AFB Destin Fort Walton B...
# 38700   Republic Airline      Fayetteville, AR: Northwest Arkansas Regional
#
#        arriving_flight_count  arrival_delayed_15_minutes_more  \
# 0                      127.0                              9.0
# 1                       73.0                             11.0
# 2                       62.0                              8.0
# 3                      166.0                             18.0
# 4                       52.0                              6.0
# ...                      ...                              ...
# 38696                    7.0                              0.0
# 38697                    1.0                              0.0
# 38698                  112.0                             10.0
# 38699                    8.0                              1.0
# 38700                  246.0                             28.0
#
#        carrier_delay_count  weather_delay_count  nas_delay_count  \
# 0                     2.51                 0.00             3.54
# 1                     5.02                 0.00             4.11
# 2                     2.63                 0.00             4.22
# 3                     8.53                 3.25             3.49
# 4                     3.15                 1.88             0.15
# ...                    ...                  ...              ...
# 38696                 0.00                 0.00             0.00
# 38697                 0.00                 0.00             0.00
# 38698                 1.79                 1.00             4.01
# 38699                 0.00                 0.00             1.00
# 38700                 7.79                 0.00             7.07
#
#        security_delay_count  late_aircraft_count  arrival_cancelled_count  \
# 0                       0.0                 2.95                      0.0
# 1                       0.0                 1.87                      0.0
# 2                       0.0                 1.15                      0.0
# 3                       0.0                 2.74                      0.0
# 4                       0.0                 0.82                      0.0
# ...                     ...                  ...                      ...
# 38696                   0.0                 0.00                      1.0
# 38697                   0.0                 0.00                      0.0
# 38698                   0.0                 3.20                      0.0
# 38699                   0.0                 0.00                      0.0
# 38700                   0.0                13.14                      0.0
#
#        arrival_diverted_count  arrival_delay_minutes  carrier_delay_minutes  \
# 0                         0.0                  264.0                  119.0
# 1                         0.0                  342.0                  125.0
# 2                         0.0                  439.0                  156.0
# 3                         1.0                 1266.0                  291.0
# 4                         0.0                  497.0                  278.0
# ...                       ...                    ...                    ...
# 38696                     0.0                    0.0                    0.0
# 38697                     0.0                    0.0                    0.0
# 38698                     0.0                  352.0                   39.0
# 38699                     0.0                   47.0                    0.0
# 38700                     0.0                 1446.0                  347.0
#
#        weather_delay_minutes  nas_delay_minutes  security_delay_minutes  \
# 0                        0.0               68.0                     0.0
# 1                        0.0              142.0                     0.0
# 2                        0.0              103.0                     0.0
# 3                      693.0              167.0                     0.0
# 4                      180.0               21.0                     0.0
# ...                      ...                ...                     ...
# 38696                    0.0                0.0                     0.0
# 38697                    0.0                0.0                     0.0
# 38698                   46.0              102.0                     0.0
# 38699                    0.0               47.0                     0.0
# 38700                    0.0              277.0                     0.0
#
#        late_aircraft_delay_minutes
# 0                             77.0
# 1                             75.0
# 2                            180.0
# 3                            115.0
# 4                             18.0
# ...                            ...
# 38696                          0.0
# 38697                          0.0
# 38698                        165.0
# 38699                          0.0
# 38700                        822.0
#
# [38701 rows x 17 columns]

# %%
#create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

#create the correlation heatmap in seaborn by applying a heatmap onto the correlation
corr = sns.heatmap(sub.corr(), annot = True, ax = ax) 
plt.savefig('corr_heatmap.png')

# %% [markdown]
# As to be expected there are strong correlations between delay counts and delay minutes for each category. Arrivals cancelled and security delays seem to have the smallest correlation to other variables. Carrier delay count and arrival delay minutes have a strong positive correlation.Late aircraft count also has a strong positive correlation to arrival delayed 15 minutes or more.

# %% [markdown]
# ## Scatterplots:

# %%
#create a scatterplot for arrival count and arrival delay 15 minutes or more
sns.lmplot(x = 'arriving_flight_count', y = 'arrival_delayed_15_minutes_more', data = df)
plt.savefig('flightcount_v_delayed.png')

# %% [markdown]
# As the number of arriving flights increase past 7500, the number of arrivals delayed 15 minutes or more become more random.

# %%
#create scatterplot for arrival delay minutes and carrier delay count
sns.lmplot(y = 'arrival_delay_minutes', x = 'carrier_delay_count', data = df)
plt.savefig('carriercount_v_delay_minutes.png')

# %%
#create scatterplot for late aircraft count and arrival delay minutes
sns.lmplot(x = 'late_aircraft_count', y = 'arrival_delay_minutes', data = df)
plt.savefig('latecount_v_delay_minutes.png')

# %% [markdown]
# These scatterplots show strong positive correlations between variables. As carrier delay count and late aircraft count increases the arrival delay minutes also increase. There are a few outliers which are suspected to be from airports that have a high volume of flights.

# %% [markdown]
# ### Pair Plots

# %%
#create subset

sub2 = sub[['arriving_flight_count', 'arrival_delayed_15_minutes_more', 'carrier_delay_count','weather_delay_count', 'nas_delay_count', 'security_delay_count', 'late_aircraft_count']]

# %%
#create pair plot
g = sns.pairplot(sub2)

# %% [markdown]
# The pair plot shows that late aircraft count and arrival dalyed 15 minutes or more have a closer relationship than any other delay type, this is followed by carrier dealys. to find what type of delays contribute the most to arrival delay 15 minutes or more I will explore both of these vaiables further. Security dealys make up the least amount of delays, I would like to explore this to see how location may play in to this.

# %% [markdown]
# ### Categorical Plots

# %%
#use histogram to visualize distribution
sns.histplot(df['late_aircraft_count'], bins = 10, kde = True)
# Out:
# <AxesSubplot:xlabel='late_aircraft_count', ylabel='Count'>

# %%
#create a categorical variable that splits delay count columns into categories
df.loc[df['late_aircraft_count'] < 3, 'Late Aircraft Category'] = 'Low count'
df.loc[df['late_aircraft_count'] >= 3 & (df['late_aircraft_count'] <6),'Late Aircraft Category'] = 'Medium count'
df.loc[df['late_aircraft_count'] >= 6, 'Late Aircraft Category'] = 'High count'

# %%
df['Late Aircraft Category'].value_counts(dropna = False)
# Out:
# Low count       14591
# Medium count    14057
# High count      10053
# Name: Late Aircraft Category, dtype: int64

# %%
# Create a categorical plot in seaborn using the late aircraft categories created above

sns.set(style="ticks")
g = sns.catplot(y='carrier_name', x='late_aircraft_count', hue="Late Aircraft Category", data=df)

# %% [markdown]
# Carriers experience a high count of late aircrafts

# %% [markdown]
# No questions previously generated can be answered at this time.
# I would like to know what affect if any does airport location have on security delays as the current exploration shows no correlation to other variables.
# Current Hypothesis: The more arriving flights an airport has, the higher the amount of carrier delays that airprt will experience.
